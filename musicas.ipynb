# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Pabllo Vittar

# %%
url = 'https://www.vagalume.com.br/pabllo-vittar/'
page = requests.get(url)
bsoup = BeautifulSoup(page.content, 'html5lib')

# %%
musicas = pd.DataFrame(columns=['id', 'artista', 'link','titulo','letra'])

musicas.set_index('id', inplace=True)

i = 0
for l in bsoup.body.find_all('a', {'class': 'nameMusic'}):

    if l.text not in list(musicas.titulo):
        musica = requests.get('https://www.vagalume.com.br' + l.attrs['href'])
        soup = BeautifulSoup(musica.content, 'html5lib')

        letra = soup.find_all('div', {'id': 'lyrics'})

        df = pd.DataFrame([[i, 'Pabllo Vittar', 'https://www.vagalume.com.br' +
                        l.attrs['href'], l.text, letra[0].text]], columns=['id', 'artista', 'link','titulo','letra'])

        df.set_index('id', inplace=True)

        musicas = pd.concat([df, musicas])

        i += 1

musicas.sort_index(inplace=True)
musicas.head()
# Out:
#           artista                                               link  \
# id
# 0   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/foll...
# 1   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/para...
# 2   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/inde...
# 3   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/amor...
# 4   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/ama-...
#
#                            titulo  \
# id
# 0   Follow Me (Ft. Rina Sawayama)
# 1        Parabéns (Part. Psirico)
# 2                   Indestrutível
# 3                     Amor de Que
# 4                 Ama Sofre Chora
#
#                                                 letra
# id
# 0   Have you ever felt like, like you're not enoug...
# 1   Hoje é um dia especialTe dou um presente você ...
# 2   Eu sei que tudo vai ficar bemE as minhas lagri...
# 3   O que os olhos não veem o coração não senteEu ...
# 4   Você diz que meu amor não é pra casarAinda ri ...

# %% [markdown]
# # Anitta

# %%
url = 'https://www.vagalume.com.br/anitta/'
page = requests.get(url)
bsoup = BeautifulSoup(page.content, 'html5lib')

# %%
for l in bsoup.body.find_all('a', {'class': 'nameMusic'}):

    if l.text not in list(musicas.titulo):
        musica = requests.get('https://www.vagalume.com.br' + l.attrs['href'])
        soup = BeautifulSoup(musica.content, 'html5lib')

        letra = soup.find_all('div', {'id': 'lyrics'})

        df = pd.DataFrame([[i, 'Anitta', 'https://www.vagalume.com.br' +
                        l.attrs['href'], l.text, letra[0].text]], columns=['id', 'artista', 'link','titulo','letra'])

        df.set_index('id', inplace=True)

        musicas = pd.concat([df, musicas])

        i += 1

musicas.sort_index(inplace=True)
musicas.tail()
# Out:
#     artista                                               link  \
# id
# 220  Anitta  https://www.vagalume.com.br/anitta/we-belong-t...
# 221  Anitta  https://www.vagalume.com.br/anitta/will-i-see-...
# 222  Anitta  https://www.vagalume.com.br/anitta/ze-do-caroc...
# 223  Anitta        https://www.vagalume.com.br/anitta/zen.html
# 224  Anitta  https://www.vagalume.com.br/anitta/zen-feat-ra...
#
#                               titulo  \
# id
# 220               We Belong Together
# 221                   Will I See You
# 222  Zé do Caroço (com JetLag Music)
# 223                              Zen
# 224                Zen (Feat. Rasel)
#
#                                                  letra
# id
# 220  I didn't mean it when I saidI didn't love you ...
# 221  When it's all said and done will I see you?Whe...
# 222  No serviço de auto-falanteDo morro do Pau da B...
# 223  Uh Uh Uh UhOlha 'cê' me faz tão bemSó de olhar...
# 224  Tu me haces sentir tan bienCon solo una mirada...

# %%
musicas.to_csv('web_crawler_musicas.csv')
