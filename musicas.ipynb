# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Pabllo Vittar

# %%
url = 'https://www.vagalume.com.br/pabllo-vittar/'
page = requests.get(url)
bsoup = BeautifulSoup(page.content, 'html5lib')

# %%
musicas = pd.DataFrame(columns=['id', 'artista', 'link','titulo','letra'])

musicas.set_index('id', inplace=True)

i = 0
for l in bsoup.body.find_all('a', {'class': 'nameMusic'}):

    if l.text not in list(musicas.titulo):
        musica = requests.get('https://www.vagalume.com.br' + l.attrs['href'])
        soup = BeautifulSoup(musica.content, 'html5lib')

        letra = soup.find_all('div', {'id': 'lyrics'})

        df = pd.DataFrame([[i, 'Pabllo Vittar', 'https://www.vagalume.com.br' +
                        l.attrs['href'], l.text, letra[0].text]], columns=['id', 'artista', 'link','titulo','letra'])

        df.set_index('id', inplace=True)

        musicas = pd.concat([df, musicas])

        i += 1

musicas.sort_index(inplace=True)
musicas.head()
# Out:
#           artista                                               link  \
# id
# 0   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/foll...
# 1   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/para...
# 2   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/amor...
# 3   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/corp...
# 4   Pabllo Vittar  https://www.vagalume.com.br/pabllo-vittar/inde...
#
#                                    titulo  \
# id
# 0           Follow Me (Ft. Rina Sawayama)
# 1                Parabéns (Part. Psirico)
# 2                             Amor de Que
# 3   Corpo Sensual (part. Mateus Carrilho)
# 4                           Indestrutível
#
#                                                 letra
# id
# 0   Have you ever felt like, like you're not enoug...
# 1   Hoje é um dia especialTe dou um presente você ...
# 2   O que os olhos não veem o coração não senteEu ...
# 3   Mandando verNo vício da batidaQuerendo se envo...
# 4   Eu sei que tudo vai ficar bemE as minhas lagri...

# %% [markdown]
# # Anitta

# %%
url = 'https://www.vagalume.com.br/anitta/'
page = requests.get(url)
bsoup = BeautifulSoup(page.content, 'html5lib')

# %%
for l in bsoup.body.find_all('a', {'class': 'nameMusic'}):

    if l.text not in list(musicas.titulo):
        musica = requests.get('https://www.vagalume.com.br' + l.attrs['href'])
        soup = BeautifulSoup(musica.content, 'html5lib')

        letra = soup.find_all('div', {'id': 'lyrics'})

        df = pd.DataFrame([[i, 'Anitta', 'https://www.vagalume.com.br' +
                        l.attrs['href'], l.text, letra[0].text]], columns=['id', 'artista', 'link','titulo','letra'])

        df.set_index('id', inplace=True)

        musicas = pd.concat([df, musicas])

        i += 1

musicas.sort_index(inplace=True)
musicas.tail()
# Out:
#     artista                                               link  \
# id
# 211  Anitta  https://www.vagalume.com.br/anitta/volta-amor....
# 212  Anitta  https://www.vagalume.com.br/anitta/we-belong-t...
# 213  Anitta  https://www.vagalume.com.br/anitta/will-i-see-...
# 214  Anitta  https://www.vagalume.com.br/anitta/ze-do-caroc...
# 215  Anitta  https://www.vagalume.com.br/anitta/zen-feat-ra...
#
#                               titulo  \
# id
# 211                       Volta Amor
# 212               We Belong Together
# 213                   Will I See You
# 214  Zé do Caroço (com JetLag Music)
# 215                Zen (Feat. Rasel)
#
#                                                  letra
# id
# 211  Por que não volta amor?Se a saudade aumentouVe...
# 212  I didn't mean it when I saidI didn't love you ...
# 213  When it's all said and done will I see you?Whe...
# 214  No serviço de auto-falanteDo morro do Pau da B...
# 215  Tu me haces sentir tan bienCon solo una mirada...
